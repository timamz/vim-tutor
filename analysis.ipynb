# %%
import pandas as pd

# %%
results = pd.read_csv('Model_Performance_Summary.csv')
results.sort_values(by='Accuracy', ascending=False).head(5)
# Out:
#                                Model   Accuracy  Avg_Levenshtein  Mean_Time  \
# 5            gpt_4.1_extended_prompt  42.045455         1.787879   2.828993
# 1        deepseek_v3_extended_prompt  37.878788        19.234848   4.932908
# 6       gpt_4.1_mini_extended_prompt  31.818182         2.446970   0.608288
# 11           qwen_7B_extended_prompt  26.515152        32.446970   2.307974
# 15  qwen_7_finetuned_extended_prompt  26.515152        32.446970   2.298814
#
#     Median_Time
# 5      3.040243
# 1      4.494800
# 6      0.497114
# 11     1.433270
# 15     1.425023

# %%
results.sort_values(by='Avg_Levenshtein').head(5)
# Out:
#                           Model   Accuracy  Avg_Levenshtein  Mean_Time  \
# 5       gpt_4.1_extended_prompt  42.045455         1.787879   2.828993
# 6  gpt_4.1_mini_extended_prompt  31.818182         2.446970   0.608288
# 2        gpt_4.1_default_prompt  25.757576         3.189394   0.676780
# 3   gpt_4.1_mini_default_prompt  23.484848         3.833333   0.613918
# 4   gpt_4.1_nano_default_prompt  12.878788         5.844697   0.399942
#
#    Median_Time
# 5     3.040243
# 6     0.497114
# 2     0.569282
# 3     0.538931
# 4     0.323860
